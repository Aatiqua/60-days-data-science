# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("statsfinal.csv")

# %%
print("Dataset Shape:")
print(df.shape)
# Out:
# Dataset Shape:
# (4600, 10)

# %%
print("Column Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Unnamed: 0', 'Date', 'Q-P1', 'Q-P2', 'Q-P3', 'Q-P4', 'S-P1', 'S-P2',
#        'S-P3', 'S-P4'],
#       dtype='str')

# %%
print("First 5 Rows:")
df.head()
# Out:
# First 5 Rows:
#    Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0           0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1           1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2           2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3           3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4           4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
#
#        S-P3      S-P4
# 0   3121.92   6466.91
# 1  19392.76  11222.62
# 2   3224.90   8163.85
# 3  17018.80  11921.36
# 4  11837.28   5048.04

# %% [markdown]
# #Target Variable
# The target variables in this dataset are *S-P1,S-P2,S-P3,and S-P4*.These columns represent the sales values for product 1 to 4.
